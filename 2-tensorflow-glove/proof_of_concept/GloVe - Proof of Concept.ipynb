# %%
from __future__ import division
from itertools import islice
from imp import reload
import sys
from random import shuffle
import datetime
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import tensorflow as tf
import corpus_tools as ct
ct = reload(ct)

# %%
def plot_with_labels(low_dim_embs, labels, filename='tsne.png', size=(100, 100)):
    assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
    figure = plt.figure(figsize=size) #in inches
    for i, label in enumerate(labels):
        x, y = low_dim_embs[i,:]
        plt.scatter(x, y)
        plt.annotate(label,
                     xy=(x, y),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')
    figure.savefig(filename)
    plt.close(figure)

def output_tsne(embeddings, filename, size=(100, 100), plot_only=1000):
    tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
    low_dim_embs = tsne.fit_transform(embeddings[:plot_only,:])
    labels = reddit_corpus.words[:plot_only]
    plot_with_labels(low_dim_embs, labels, filename, size)
    
def batchify(batch_size, *sequences):
    for i in range(0, len(sequences[0]), batch_size):
        yield tuple(sequence[i:i+batch_size] for sequence in sequences)

# %%
COUNT_MAX = 100
SCALING_FACTOR = 3 / 4
EMBEDDING_SIZE = 150
CONTEXT_SIZE = 10
MIN_OCCURRENCES = 25
LEARNING_RATE = 0.05
NUM_EPOCHS = 50
BATCH_SIZE = 512
REPORT_BATCH_SIZE = 10000
TSNE_EPOCH_FREQ = 1

# %%
# load the corpus

# reddit_corpus = ct.RedditCorpus("/media/grady/PrimeMover/Datasets/RC_2015-01-1m_sample", size=CONTEXT_SIZE)
file_path = "/Users/zl/Desktop/课件2020/网络空间安全综合实验/glove-本地/tensorflow-glove/data"
reddit_corpus = ct.RedditCorpus(file_path+"/RC_2005-12",size=CONTEXT_SIZE,)
reddit_corpus.fit(min_occurrences=MIN_OCCURRENCES)
vocab_size = len(reddit_corpus.words)
print("Unique tokens: {}".format(vocab_size))
print("Non-zero elems of cooccurrence matrix: {}".format(len(reddit_corpus.cooccurrence_matrix)))
# Out:
# Unique tokens: 322
# Non-zero elems of cooccurrence matrix: 60558

# %%
def device_for_node(n):
  if n.type == "MatMul":
    return "/gpu:0"
  else:
    return "/cpu:0"

graph = tf.Graph()

with graph.as_default():
    with graph.device(device_for_node):
        count_max = tf.constant([COUNT_MAX], dtype=tf.float32)
        scaling_factor = tf.constant([SCALING_FACTOR], dtype=tf.float32)
        focal_input = tf.placeholder(tf.int32, shape=[BATCH_SIZE])
        context_input = tf.placeholder(tf.int32, shape=[BATCH_SIZE])
        cooccurrence_count = tf.placeholder(tf.float32, shape=[BATCH_SIZE])


        focal_embeddings = tf.Variable(
            tf.random_uniform([vocab_size, EMBEDDING_SIZE], 1.0, -1.0)
        )

        context_embeddings = tf.Variable(
            tf.random_uniform([vocab_size, EMBEDDING_SIZE], 1.0, -1.0)
        )

        focal_biases = tf.Variable(
            tf.random_uniform([vocab_size], 1.0, -1.0)
        )

        context_biases = tf.Variable(
            tf.random_uniform([vocab_size], 1.0, -1.0)
        )

        focal_embedding = tf.nn.embedding_lookup([focal_embeddings], focal_input)
        context_embedding = tf.nn.embedding_lookup([context_embeddings], context_input)
        focal_bias = tf.nn.embedding_lookup([focal_biases], focal_input)
        context_bias = tf.nn.embedding_lookup([context_biases], context_input)

        weighting_factor = tf.minimum(
            1.0, 
            tf.pow(
                tf.div(cooccurrence_count, count_max), 
                scaling_factor
            )
        )
        
        embedding_product = tf.reduce_sum(tf.multiply(focal_embedding, context_embedding), 1) 
        
        log_cooccurrences = tf.log(tf.to_float(cooccurrence_count))
        
        distance_expr = tf.square(tf.add_n([
            embedding_product,
            focal_bias,
            context_bias,
            tf.negative(log_cooccurrences)
        ]))

        single_losses = tf.multiply(weighting_factor, distance_expr)
        total_loss = tf.reduce_sum(single_losses)
        optimizer = tf.train.AdagradOptimizer(LEARNING_RATE).minimize(total_loss)
        
        combined_embeddings = tf.add(focal_embeddings, context_embeddings)

# okay, so the graph is maybe built... Time to run it!
# Out:
# WARNING:tensorflow:From <ipython-input-5-cabd9269d2ed>:42: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:From <ipython-input-5-cabd9269d2ed>:49: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /Users/zl/anaconda3/lib/python3.7/site-packages/tensorflow/python/training/adagrad.py:76: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
cooccurrences = [(pos[0], pos[1], count) for pos, count in reddit_corpus.cooccurrence_matrix.items()]

i_indices, j_indices, counts = zip(*cooccurrences)

batches = list(batchify(BATCH_SIZE, i_indices, j_indices, counts))

# %%
print("Begin training: {}".format(datetime.datetime.now().time()))
print("=================")
sys.stdout.flush()
with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    for epoch in range(NUM_EPOCHS):
        shuffle(batches)
        print("Batches shuffled")
        print("-----------------")
        sys.stdout.flush()
        accumulated_loss = 0
        for batch_index, batch in enumerate(batches):
            i_s, j_s, counts = batch
            if len(counts) != BATCH_SIZE:
                continue
            feed_dict = {focal_input: i_s, context_input: j_s, cooccurrence_count: counts}
            _, total_loss_,  = session.run([optimizer, total_loss], feed_dict=feed_dict)            
            accumulated_loss += total_loss_
            if (batch_index + 1) % REPORT_BATCH_SIZE == 0:
                print("Epoch: {0}/{1}".format(epoch + 1, NUM_EPOCHS))
                print("Batch: {0}/{1}".format(batch_index + 1, len(batches)))
                print("Average loss: {}".format(accumulated_loss / REPORT_BATCH_SIZE))
                print("-----------------")
                sys.stdout.flush()
                accumulated_loss = 0
        if (epoch + 1) % TSNE_EPOCH_FREQ == 0:
            print("Outputting t-SNE: {}".format(datetime.datetime.now().time()))
            print("-----------------")
            sys.stdout.flush()
            current_embeddings = combined_embeddings.eval()
            output_tsne(current_embeddings, "epoch{:02d}.png".format(epoch + 1))
        print("Epoch finished: {}".format(datetime.datetime.now().time()))
        print("=================")
        sys.stdout.flush()
    final_embeddings = combined_embeddings.eval()
print("End: {}".format(datetime.datetime.now().time()))
# Out:
# Begin training: 13:54:39.906211
# =================
# WARNING:tensorflow:From /Users/zl/anaconda3/lib/python3.7/site-packages/tensorflow/python/util/tf_should_use.py:193: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Batches shuffled
# -----------------
# Outputting t-SNE: 13:54:40.057978
# -----------------
# Epoch finished: 13:54:50.706395
# =================
# Batches shuffled
# -----------------
# Outputting t-SNE: 13:54:50.792754
# -----------------
# Epoch finished: 13:55:01.669014
# =================
# Batches shuffled
# -----------------
# Outputting t-SNE: 13:55:01.779330
# -----------------
# Epoch finished: 13:55:13.282690
# =================
# Batches shuffled
# -----------------
# Outputting t-SNE: 13:55:13.370554
# -----------------
# Epoch finished: 13:55:24.598711
# =================
# Batches shuffled
# -----------------
# Outputting t-SNE: 13:55:24.681413
# -----------------
# Epoch finished: 13:55:35.865132
# =================
# Batches shuffled
# -----------------
# Outputting t-SNE: 13:55:35.944383
# -----------------
# Epoch finished: 13:55:49.620500
# =================
# Batches shuffled
# -----------------
# Outputting t-SNE: 13:55:49.700837
# -----------------
# Epoch finished: 13:56:01.402891
# =================
# Batches shuffled
# -----------------
# Outputting t-SNE: 13:56:01.482667
# -----------------
# Epoch finished: 13:56:15.784781
# =================
# Batches shuffled
# -----------------
# Outputting t-SNE: 13:56:15.895759
# -----------------
# Epoch finished: 13:56:28.452174
# =================
# Batches shuffled
# -----------------
# Outputting t-SNE: 13:56:28.535510
# -----------------
# Epoch finished: 13:56:41.183086
# =================
# Batches shuffled
# -----------------
# Outputting t-SNE: 13:56:41.261751
# -----------------
# Epoch finished: 13:56:52.421940
# =================
# Batches shuffled
# -----------------
# Outputting t-SNE: 13:56:52.513493
# -----------------
# Epoch finished: 13:57:05.739194
# =================
# Batches shuffled
# -----------------
# Outputting t-SNE: 13:57:05.835779
# -----------------
# Epoch finished: 13:57:19.433942
# =================
# Batches shuffled
# -----------------
# Outputting t-SNE: 13:57:19.516568
# -----------------
# Epoch finished: 13:57:30.894969
# =================
# Batches shuffled
# -----------------
# Outputting t-SNE: 13:57:30.982956
# -----------------
# Epoch finished: 13:57:43.207138
# =================
# Batches shuffled
# -----------------
# Outputting t-SNE: 13:57:43.290543
# -----------------
# Epoch finished: 13:57:54.739044
# =================
# Batches shuffled
# -----------------
# Outputting t-SNE: 13:57:54.825670
# -----------------
# Epoch finished: 13:58:06.100482
# =================
# Batches shuffled
# -----------------
# Outputting t-SNE: 13:58:06.187424
# -----------------
# Epoch finished: 13:58:16.726915
# =================
# Batches shuffled
# -----------------
# Outputting t-SNE: 13:58:16.828789
# -----------------
# Epoch finished: 13:58:27.220456
# =================
# Batches shuffled
# -----------------
# Outputting t-SNE: 13:58:27.306206
# -----------------
# Epoch finished: 13:58:37.894149
# =================
# Batches shuffled
# -----------------
# Outputting t-SNE: 13:58:37.990314
# -----------------
# Epoch finished: 13:58:49.482124
# =================
# Batches shuffled
# -----------------
# Outputting t-SNE: 13:58:49.559273
# -----------------
# Epoch finished: 13:58:59.933324
# =================
# Batches shuffled
# -----------------
# Outputting t-SNE: 13:59:00.031285
# -----------------
# Epoch finished: 13:59:10.505058
# =================
# Batches shuffled
# -----------------
# Outputting t-SNE: 13:59:10.584673
# -----------------
# Epoch finished: 13:59:21.652843
# =================
# Batches shuffled
# -----------------
# Outputting t-SNE: 13:59:21.742153
# -----------------
# Epoch finished: 13:59:32.723348
# =================
# Batches shuffled
# -----------------
# Outputting t-SNE: 13:59:32.801631
# -----------------
# Epoch finished: 13:59:42.637229
# =================
# Batches shuffled
# -----------------
# Outputting t-SNE: 13:59:42.717532
# -----------------
# Epoch finished: 13:59:52.792327
# =================
# Batches shuffled
# -----------------
# Outputting t-SNE: 13:59:52.876715
# -----------------
# Epoch finished: 14:00:03.414836
# =================
# Batches shuffled
# -----------------
# Outputting t-SNE: 14:00:03.495378
# -----------------
# Epoch finished: 14:00:13.163986
# =================
# Batches shuffled
# -----------------
# Outputting t-SNE: 14:00:13.241343
# -----------------
# Epoch finished: 14:00:23.099472
# =================
# Batches shuffled
# -----------------
# Outputting t-SNE: 14:00:23.180552
# -----------------
# Epoch finished: 14:00:33.813329
# =================
# Batches shuffled
# -----------------
# Outputting t-SNE: 14:00:33.892497
# -----------------
# Epoch finished: 14:00:45.198933
# =================
# Batches shuffled
# -----------------
# Outputting t-SNE: 14:00:45.284024
# -----------------
# Epoch finished: 14:00:55.332929
# =================
# Batches shuffled
# -----------------
# Outputting t-SNE: 14:00:55.413013
# -----------------
# Epoch finished: 14:01:06.721272
# =================
# Batches shuffled
# -----------------
# Outputting t-SNE: 14:01:06.803146
# -----------------
# Epoch finished: 14:01:17.321905
# =================
# Batches shuffled
# -----------------
# Outputting t-SNE: 14:01:17.401483
# -----------------
# Epoch finished: 14:01:27.470744
# =================
# Batches shuffled
# -----------------
# Outputting t-SNE: 14:01:27.550914
# -----------------
# Epoch finished: 14:01:38.746387
# =================
# Batches shuffled
# -----------------
# Outputting t-SNE: 14:01:38.841132
# -----------------
# Epoch finished: 14:01:49.851386
# =================
# Batches shuffled
# -----------------
# Outputting t-SNE: 14:01:49.957720
# -----------------
# Epoch finished: 14:02:01.449277
# =================
# Batches shuffled
# -----------------
# Outputting t-SNE: 14:02:01.529218
# -----------------
# Epoch finished: 14:02:12.299119
# =================
# Batches shuffled
# -----------------
# Outputting t-SNE: 14:02:12.379969
# -----------------
# Epoch finished: 14:02:22.885751
# =================
# Batches shuffled
# -----------------
# Outputting t-SNE: 14:02:22.964587
# -----------------
# Epoch finished: 14:02:33.568483
# =================
# Batches shuffled
# -----------------
# Outputting t-SNE: 14:02:33.647295
# -----------------
# Epoch finished: 14:02:44.595574
# =================
# Batches shuffled
# -----------------
# Outputting t-SNE: 14:02:44.685848
# -----------------
# Epoch finished: 14:02:56.343033
# =================
# Batches shuffled
# -----------------
# Outputting t-SNE: 14:02:56.448688
# -----------------
# Epoch finished: 14:03:07.196983
# =================
# Batches shuffled
# -----------------
# Outputting t-SNE: 14:03:07.285273
# -----------------
# Epoch finished: 14:03:17.890836
# =================
# Batches shuffled
# -----------------
# Outputting t-SNE: 14:03:17.970972
# -----------------
# Epoch finished: 14:03:29.120958
# =================
# Batches shuffled
# -----------------
# Outputting t-SNE: 14:03:29.202027
# -----------------
# Epoch finished: 14:03:40.830216
# =================
# Batches shuffled
# -----------------
# Outputting t-SNE: 14:03:40.913998
# -----------------
# Epoch finished: 14:03:51.757553
# =================
# Batches shuffled
# -----------------
# Outputting t-SNE: 14:03:51.887342
# -----------------
# Epoch finished: 14:04:03.760719
# =================
# End: 14:04:03.768866

# %%
output_tsne(final_embeddings, "final_big-minibatch-1m.png", plot_only=4000)
